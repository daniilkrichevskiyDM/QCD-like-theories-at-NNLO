# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # New code

# %%
file_path_Kulkarni = '/Users/daniilkrichevskiy/Desktop/Project SIMP at NLO/Fit the LECs/Infinite_volume_fit/Data/latticeresultsKulkarniFull_InfiniteVolume.csv'
data_Kulkarni =  np.loadtxt(file_path_Kulkarni , delimiter = ';', skiprows = 1) # Use skip_header=1 if you want to skip the header row

table6 = data_Kulkarni[:32]        
table7 = data_Kulkarni[32:63]      
table8 = data_Kulkarni[63:]

# %%
def extract_rows_by_value(matrix):
    """
    The function takes a 2D NumPy array and extracts the rows where the first column contains the values 6.9, 7.05, or 7.2.
    """
    values_to_extract = {6.9, 7.05, 7.2}  # Устанавливаем нужные значения

    # Извлекаем строки, соответствующие указанным значениям
    extracted_6_9 = matrix[np.isclose(matrix[:, 0], 6.9)]
    extracted_7_05 = matrix[np.isclose(matrix[:, 0], 7.05)]
    extracted_7_2 = matrix[np.isclose(matrix[:, 0], 7.2)]    

    return extracted_6_9, extracted_7_05, extracted_7_2

# %%
def process_matrices_for_different_betas(matrices):
   
    results = []
    
    for matrix in matrices:
        mPiA = matrix[:, 3]  # mass of type A
        DmPiA = matrix[:, 4]  # error of mass of type A
        mPiASquared = mPiA * mPiA  # Squared mass of type A
        DmPiASquared = 2 * mPiA * DmPiA  # error of squared mass of type A

        mPiC = matrix[:, 5]  # mass of type C
        DmPiC = matrix[:, 6]  # error of mass of type C
        mPiCSquared = mPiC * mPiC  # Squared mass of type C
        DmPiCSquared = 2 * mPiC * DmPiC  # error of squared mass of type C

        ratioOfPionMasses =  mPiA/mPiC
        DratioOfPionMasses = (mPiA*DmPiC+mPiC*DmPiA)/mPiC**2

        # X-axis
        mAverage = matrix[:, 11]  # average PCAC mass
        DmAverage = matrix[:, 12]  # error of average PCAC mass

        mu = mAverage[-1]  # mu stays fixed
        Dmu = DmAverage[-1]  # error of mu

        r = -1 + 2 * mAverage / mu  # ratio r=md/mu!!!
        Dr = 2 / (mu ** 2) * (mAverage * Dmu + mu * DmAverage)  # error of r=mu/md

        # Store results as dictionary
        results.append({
            "mPiA": mPiA,
            "DmPiA": DmPiA,
            "mPiC": mPiC,
            "DmPiC": DmPiC,
            "r": r,
            "Dr": Dr,
            "ratioOfPionMasses": ratioOfPionMasses,
            "DratioOfPionMasses": DratioOfPionMasses
        })
    
    return results

# %%
def plot_pion_mass_ratios(results):
    import matplotlib.pyplot as plt

    titles = ['β=6.9', 'β=7.05', 'β=7.2']
    num_points_to_plot = [5, 4, 5]  # сколько точек брать с конца для каждого β

    plt.figure(figsize=(10, 6))

    for idx, res in enumerate(results):
        n = num_points_to_plot[idx] if idx < len(num_points_to_plot) else len(res['r'])

        r = res['r'][-n:]
        ratio = res['ratioOfPionMasses'][-n:]
        x_error = res['Dr'][-n:]
        y_error = res['DratioOfPionMasses'][-n:]

        plt.errorbar(r, ratio, yerr=y_error, xerr=x_error, fmt='d', label=titles[idx] if idx < len(titles) else f"β-{idx+1}")

    plt.xlabel(r'$r = m_d^{\mathrm{PCAC}}/m_u^{\mathrm{PCAC}}$', fontsize=25)
 
    plt.ylabel("   $M^2_{\pi,1}$/$M^2_{\pi,3}$", fontsize=25)
    #plt.title("mPiA / mPiC Ratios for Different β")
    plt.xlim(0, 6)
    plt.ylim(0.9, 1.25)
    plt.grid(True)
    plt.legend(fontsize = 20, loc='upper left')
    plt.tight_layout()
    plt.tick_params(axis='y', labelsize=20)
    plt.tick_params(axis='x', labelsize=20)
    plt.savefig("/Users/daniilkrichevskiy/Desktop/New plots/mPiA_over_mPiC_combined.png", dpi=250, bbox_inches='tight')
    plt.show()

# %%
matrices_with_different_betas = extract_rows_by_value(table7)
results = process_matrices_for_different_betas(matrices_with_different_betas)
plot_pion_mass_ratios(results)

# %%
# Load the CSV file
file_path_Kulkarni = '/Users/daniilkrichevskiy/Desktop/4. Fit the LECs/data/latticeresultsKulkarniSP4table7.txt'  # Replace with your actual file path or upload the file

# Read the CSV into a NumPy array
data_Kulkarni =  np.loadtxt(file_path_Kulkarni , delimiter = ';', skiprows = 1) # Use skip_header=1 if you want to skip the header row

#all masses here are PCAC masses and given in termas of a^(-1)

#y-axis

mPiA = data_Kulkarni[:,4] #mass of type A
DmPiA = data_Kulkarni[:,5] #error of mass of type A
mPiASquared = mPiA*mPiA #Squared mass of type A
DmPiASquared = 2*mPiA*DmPiA #error of squared mass of type A

mPiC = data_Kulkarni[:,6] #mass of type C
DmPiC = data_Kulkarni[:,7] #error of mass of type C
mPiCSquared = mPiC*mPiC #Squared mass of type C
DmPiCSquared = 2*mPiC*DmPiC #error of squared mass of type C

fA = data_Kulkarni[:,8]  #decay constant of type A
DfA = data_Kulkarni[:,9] #error of decay constant of type A

fC = data_Kulkarni[:,10] #decay constant of type C
DfC = data_Kulkarni[:,11] #error of decay constant of type C

#we can also consider x2A=mA^2/fA^2 and x2C=mC^2/fC^2  
x2A = mPiASquared/(fA**2)
Dx2A = 2*(mPiASquared*fA*DfA+fA**2*mPiA*DmPiA)/fA**4


# x2C = mPiCSquared/(fA**2)
# Dx2C = 2*(mPiCSquared*fA*DfA+fA**2*mPiC*DmPiA)/fA**4

x2C = mPiCSquared/(fC**2)
Dx2C = 2*(mPiCSquared*fC*DfC+fC**2*mPiC*DmPiC)/fC**4

#x-axis
mAverage = data_Kulkarni[:,12] #average PCAC mass
DmAverage = data_Kulkarni[:,13] #average PCAC mass

mu =  mAverage[-1] #mu stays fixed
Dmu = DmAverage[-1] #error of mu 

r = -1 + 2*mAverage/mu; #ratio r=mu/md
Dr = 2/(mu**2)*(mAverage*Dmu + mu*DmAverage)  #error of r=mu/md

Kulkarni_x = np.vstack((r[-6:],r[-6:],r[-6:]))
Kulkarni_dx = np.vstack((Dr[-6:],Dr[-6:],Dr[-6:]))
Kulkarni_y = np.vstack((mPiASquared[-6:], mPiCSquared[-6:], fA[-6:]))
Kulkarni_dy = np.vstack((DmPiASquared[-6:], DmPiCSquared[-6:], DfA[-6:]))

# %%
# Plot data from Kulkarni et al.

plt.errorbar(r, mPiA, yerr = DmPiA, xerr = Dr, marker='o', label='pi_A', linestyle='None')  # 'marker' adds points at each (x, y) value
plt.errorbar(r, mPiC, yerr = DmPiC, xerr = Dr, marker='s', label='pi_C', linestyle='None')  # 'marker' adds points at each (x, y) value

plt.errorbar(r, fA, yerr = DfA, xerr = Dr, marker='o', label='f_A', linestyle='None')  # 'marker' adds points at each (x, y) value
plt.errorbar(r, fC, yerr = DfC,  xerr = Dr, marker='s', label='f_C', linestyle='None')  # 'marker' adds points at each (x, y) value

plt.xlabel('PCAC m_d/m_u')      # Label for the x-axis
plt.ylabel('in a^(-1) units')      # Label for the y-axis
plt.title('Figure 6, beta=6.9, m_rho / m_pi =1.46')    # Title of the plot

plt.xlim(0, 21)
plt.ylim(0.0, 1.3)
plt.grid(True)   
plt.legend()
plt.show()

# %%
# Plot of the squared masses

plt.errorbar(r, mPiASquared, yerr = DmPiASquared, xerr = Dr, marker='o', label='mPiASquared', linestyle='None')  # 'marker' adds points at each (x, y) value
plt.errorbar(r, mPiCSquared, yerr = DmPiCSquared, xerr = Dr, marker='s', label=' mPiCSquared', linestyle='None')  # 'marker' adds points at each (x, y) value


plt.xlabel('PCAC m_d/m_u')      # Label for the x-axis
plt.ylabel('squared pion masses, in a^(-2) units')      # Label for the y-axis
plt.title('beta=6.9, m_rho / m_pi =1.46')    # Title of the plot


plt.xlim(0, 20)
plt.ylim(0.0, 1.2)
plt.grid(True)   
plt.legend()
plt.show()

# %%
# Plot of the ratios x2

plt.errorbar(r, x2A, yerr = Dx2A, xerr = Dr, marker='o', label='x2_A', linestyle='None')  # 'marker' adds points at each (x, y) value
plt.errorbar(r, x2C, yerr = Dx2C, xerr = Dr, marker='s', label='x2_C', linestyle='None')  # 'marker' adds points at each (x, y) value
#plt.errorbar(r, x2C_new, yerr = Dx2C_new, xerr = Dr, marker='s', label='x2_C with fC', linestyle='None')  # 'marker' adds points at each (x, y) value

plt.xlabel('PCAC m_d/m_u')      # Label for the x-axis
plt.ylabel('x2=m^2/f^2')      # Label for the y-axis
plt.title('beta=6.9, m_rho / m_pi =1.46')    # Title of the plot

plt.grid(True)   
plt.legend()
plt.show()

# %%
# Load the CSV files for scattering

"""
file_path_Zierler_energy_levels = 'data/tables_from_scattering_paper/energy_levels_only_biggest_ansambles.csv'  # Replace with your actual file path or upload the file
data_Zierler_energy_levels =  np.loadtxt(file_path_Zierler_energy_levels, delimiter = ';', skiprows = 1) # Use skip_header=1 if you want to skip the header row

file_path_Zierler_Figure_3 = 'data/tables_from_scattering_paper/effective_range_parameters.csv'
data_Zierler_Figure_3 = np.loadtxt(file_path_Zierler_Figure_3, delimiter = ',', skiprows = 1)

file_path_Dengler_Figure_3_new = '/Users/daniilkrichevskiy/Desktop/4. Fit the LECs/data/new_data_scattering/tables/effective_range_parameters.csv'
data_Dengler_Figure_3_new = np.loadtxt(file_path_Dengler_Figure_3_new, delimiter = ',', skiprows = 1)

a_mpi = data_Dengler_Figure_3_new[:,2] #pion mass
D_a_mpi_lower = data_Dengler_Figure_3_new[:,3] #pion mass lower error
D_a_mpi_lower = data_Dengler_Figure_3_new[:,4] #pion mass upper error

a0_mpi = data_Dengler_Figure_3_new[:,5] #scattering length
D_a0_mpi_lower = data_Dengler_Figure_3_new[:,6] #scattering length lower error
D_a0_mpi_upper = data_Dengler_Figure_3_new[:,7] #scattering length upper error   

mpi_fpi = data_Dengler_Figure_3_new[:,11] #mpi/fpi (x-axis)
D_mpi_fpi_lower = data_Dengler_Figure_3_new[:,12] #mpi/fpi (x-axis) lower error
D_mpi_fpi_upper = data_Dengler_Figure_3_new[:,13] #mpi/fpi (x-axis) upper error
"""
#if we are rather interested in the most trustable Figure 5.3
file_path_Dengler_Figure_5_3_new = '/Users/daniilkrichevskiy/Desktop/4. Fit the LECs/data/new_data_scattering/tables/effective_range_parameters_Fig5.3.csv'
data_Dengler_Figure_5_3_new = np.loadtxt(file_path_Dengler_Figure_5_3_new, delimiter = ',', skiprows = 1)

a_mpi = data_Dengler_Figure_5_3_new[:,2] #pion mass
D_a_mpi_lower = data_Dengler_Figure_5_3_new[:,3] #pion mass lower error
D_a_mpi_lower = data_Dengler_Figure_5_3_new[:,4] #pion mass upper error

a0_mpi = data_Dengler_Figure_5_3_new[:,5] #scattering length
D_a0_mpi_lower = data_Dengler_Figure_5_3_new[:,6] #scattering length lower error
D_a0_mpi_upper = data_Dengler_Figure_5_3_new[:,7] #scattering length upper error   

mpi_fpi = data_Dengler_Figure_5_3_new[:,11] #mpi/fpi (x-axis)
D_mpi_fpi_lower = data_Dengler_Figure_5_3_new[:,12] #mpi/fpi (x-axis) lower error
D_mpi_fpi_upper = data_Dengler_Figure_5_3_new[:,13] #mpi/fpi (x-axis) upper error

Maas_x = mpi_fpi
Maas_y = a0_mpi
Maas_dy = np.maximum(D_a0_mpi_lower, D_a0_mpi_upper)

# %%
# Plot the data from Zierler, Maas, Dengler

# Define the ChPT LO prediction
def func_LO(x):
    return (2 / np.pi) * (1 / 32) * x**2
# Generate values for the function
x_func = np.linspace(0, 6, 100)  # x values for the function
y_func_LO = func_LO(x_func)  # y values for the function  



plt.errorbar(mpi_fpi[:1], a0_mpi[:1], yerr = (D_a0_mpi_lower[:1],D_a0_mpi_upper[:1]), xerr = (D_mpi_fpi_lower[:1], D_mpi_fpi_upper[:1]), marker='o', label='beta=6.9', linestyle='None')
plt.errorbar(mpi_fpi[1:3], a0_mpi[1:3], yerr = (D_a0_mpi_lower[1:3],D_a0_mpi_upper[1:3]), xerr = (D_mpi_fpi_lower[1:3], D_mpi_fpi_upper[1:3]), marker='o', label='beta=7.05', linestyle='None')
plt.errorbar(mpi_fpi[3:], a0_mpi[3:], yerr = (D_a0_mpi_lower[3:],D_a0_mpi_upper[3:]), xerr = (D_mpi_fpi_lower[3:], D_mpi_fpi_upper[3:]), marker='o', label='beta=7.20', linestyle='None')
plt.plot(x_func, y_func_LO, label = "ChPT LO prediction", color='blue', linestyle='--')

plt.xlabel('m_pi/f_pi')      # Label for the x-axis
plt.ylabel('a_0*m_pi')      # Label for the y-axis
plt.title('Scattering lenght (Figure 5.3 with new data)')    # Title of the plot


plt.xlim(0, 6)
plt.ylim(0.0, 1)
plt.grid(True)   
plt.legend()
plt.show()
